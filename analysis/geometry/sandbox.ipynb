# %%
import networkx as nx
import numpy as np
from parser import MERA

# %%
M = MERA("W_test.txt")

# %%
# %matplotlib notebook
import pydot
from networkx.drawing.nx_pydot import graphviz_layout
pos = graphviz_layout(M.G, prog="dot", root="U31")
nx.draw(M.G, pos, with_labels=True)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
# /home/abid/.local/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/abid/.local/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
M.level_list
# Out:
# {1: ['U0', 'U1', 'U2', 'U3', 'U4'],
#  2: ['U5', 'U6', 'U7', 'U8'],
#  3: ['U9', 'U10', 'U11'],
#  4: ['U12', 'U13', 'U14'],
#  5: ['U15'],
#  6: ['U16'],
#  7: ['U17'],
#  8: ['U18'],
#  9: ['U19'],
#  10: ['U20'],
#  11: ['U21'],
#  12: ['U22'],
#  13: ['U23'],
#  14: ['U24'],
#  15: ['U25'],
#  16: ['U26'],
#  17: ['U27'],
#  18: ['U28'],
#  19: ['U29'],
#  20: ['U30'],
#  21: ['U31']}

# %%
[len(M.shortest_paths["U{}".format(M.L - 1)][i]) for i in range(M.L)]
# Out:
# [10,
#  12,
#  12,
#  12,
#  12,
#  11,
#  12,
#  14,
#  15,
#  15,
#  15,
#  15,
#  14,
#  14,
#  14,
#  14,
#  12,
#  12,
#  11,
#  9,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  7,
#  9,
#  9,
#  9,
#  9,
#  8]

# %%
level_map = np.zeros((M.L, M.L))
for i in range(M.L):
    for j in range(M.L):
        level_map[i,j] = M.get_largest_level_from_path(i,j)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(level_map)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sp = dict(nx.all_pairs_shortest_path(M.G))
sp["U19"][1]
# Out:
# ['U19', 'U5', 'U0', 1]

# %%
M.get_path(3,25)
# Out:
# [3, 'U0', 'U5', 'U19', 'U22', 'U23', 'U10', 'U3', 25]

# %%
M.depth
# Out:
# 21

# %%
M.level_list
# Out:
# {1: ['U0', 'U1', 'U2', 'U3', 'U4'],
#  2: ['U5', 'U6', 'U7', 'U8'],
#  3: ['U9', 'U10', 'U11'],
#  4: ['U12', 'U13', 'U14'],
#  5: ['U15'],
#  6: ['U16'],
#  7: ['U17'],
#  8: ['U18'],
#  9: ['U19'],
#  10: ['U20'],
#  11: ['U21'],
#  12: ['U22'],
#  13: ['U23'],
#  14: ['U24'],
#  15: ['U25'],
#  16: ['U26'],
#  17: ['U27'],
#  18: ['U28'],
#  19: ['U29'],
#  20: ['U30'],
#  21: ['U31']}

# %%
sp = dict(nx.all_pairs_shortest_path(M.G))
for i in range(M.depth):
    lvl = i + 1
    for U in M.level_list[lvl]:
        try:
            sp[U][i]
            sp[U][j]
            print(U)
            return lvl
        except:
            pass

# %%
get_largest_level_from_path(M, 0, 1)
# Out:
# U5
# 2
