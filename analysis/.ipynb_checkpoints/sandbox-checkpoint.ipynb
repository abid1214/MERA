# %%
L = 32
U_list = [None]*L
p_list = [None]*L
filename = "W_10.txt"

# %%
with open(filename, 'r') as fp:
    fp.readline()
    i = 0
    for line in fp:
        data = list(map(int, line.split()[:-1]))
        U_list[i]=data
        i += 1

# %%
U_list
# Out:
# [[8, 8, 11],
#  [7, 11, 11],
#  [12, 15, 15],
#  [1, 2, 4],
#  [7, 7, 12],
#  [1, 1, 5],
#  [22, 25, 25],
#  [4, 5, 9],
#  [10, 14, 14],
#  [9, 9, 13],
#  [4, 4, 12],
#  [27, 27, 30],
#  [12, 12, 17],
#  [20, 22, 23],
#  [10, 17, 17],
#  [0, 0, 10],
#  [28, 29, 31],
#  [10, 10, 18],
#  [6, 16, 18],
#  [20, 23, 24],
#  [3, 18, 18],
#  [26, 31, 31],
#  [6, 13, 20],
#  [3, 20, 20],
#  [24, 30, 30],
#  [6, 6, 24],
#  [3, 24, 24],
#  [3, 3, 26],
#  [19, 26, 28],
#  [19, 21, 28],
#  [19, 28, 28],
#  [19, 19, 19]]

# %%
import networkx as nx
G = nx.Graph()

# %%
for i in range(L):
    G.add_node(i)
    p_list[i] = i

# %%
for k, U in enumerate(U_list):
    lbl = "U" + str(k)
    G.add_node(lbl)
    for i in range(U[0], U[2] + 1):
        G.add_edge(p_list[i], lbl)
        p_list[i] = lbl

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.figure()
nx.draw_spring(G, with_labels=True, font_weight='bold')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/abid/.local/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
sp = dict(nx.all_pairs_shortest_path(G))

# %%
from parser import load_MERA

# %%
G = load_MERA("W_10.txt")

# %%
plt.figure()
nx.draw_spring(G, with_labels=True, font_weight='bold')
# Out:
# <img src="data:image/png;base64,..." width="640">
